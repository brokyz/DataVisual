# %% [markdown]
# # 上机作业 8
# # 32019070233 张博强 大数据2班

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image

def getImage(path,zoom=0.07):
    img = Image.open(path)  
    img.thumbnail((512, 512), Image.Resampling.LANCZOS) 
    return OffsetImage(img,zoom=zoom)
    
paths =np.arange(1,11,1)
N=10
x = np.sort(np.random.randn(N))+5
y = np.sort(np.random.randn(N))+5

fig, ax = plt.subplots(figsize=(4,4),dpi =100)
ax.scatter(x, y) 
plt.xlabel("X Axis",fontsize=12)
plt.ylabel("Y Axis",fontsize=12)
plt.yticks(ticks=np.arange(5,8,1))
artists = []
for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage('img/'+str(path)+'.jpg'), (x0, y0), frameon=True)
    artists.append(ax.add_artist(ab))
plt.show()

# %%
from plotnine.data import mtcars
import matplotlib.pyplot as plt

x = mtcars['wt']
y = mtcars['mpg']
size = mtcars['disp']
fill = mtcars['disp']

fig, ax = plt.subplots(figsize=(5, 4))

scatter = ax.scatter(x, y, c=fill, s=size, linewidths=0.5,edgecolors="k", cmap='RdYlBu_r')
cbar = plt.colorbar(scatter)
cbar.set_label('disp')
                    
handles,labels = scatter.legend_elements(prop="sizes",alpha=0.6,num=5)
ax.legend(handles,labels,loc="upper right",title="Sizes")
plt.show()

# %%
from plotnine.data import mtcars
import matplotlib.pyplot as plt

x = mtcars['wt']
y = mtcars['mpg']
size = mtcars['disp']

fig, ax = plt.subplots(figsize=(5, 4))

scatter = ax.scatter(x, y, s=size, linewidths=0.5,edgecolors="k")
cbar = plt.colorbar(scatter)
cbar.set_label('disp')
                    
handles,labels = scatter.legend_elements(prop="sizes",alpha=0.6,num=5)
ax.legend(handles,labels,loc="upper right",title="Sizes")
plt.show()

# %%
import pandas as pd
import numpy as np
from plotnine import *
from plotnine.data import mtcars

base_plot=(ggplot(mtcars,aes(x='wt',y='mpg'))
    +geom_point(aes(size='disp',fill='disp'),shape='o',colour="black")
    +scale_fill_gradient2(low="#377EB8",high="#E41A1C",limits =(0,np.max(mtcars.disp)),midpoint=np.mean(mtcars.disp))
    +scale_size_area(max_size=12)
    +geom_text(label=mtcars.disp,nudge_x=0.3,nudge_y=0.3)
    +theme(
        axis_title=element_text(size=18,face="plain",color="black"),
        axis_text=element_text(size=16,face="plain",color="black"),
        aspect_ratio =1.2,
        figure_size =(5,5),
        dpi=100
    ))
print(base_plot)

# %%
import pandas as pd
import numpy as np
from plotnine import *
from plotnine.data import mtcars

base_plot=(ggplot(mtcars,aes(x='wt',y='mpg'))
    +geom_point(aes(size='disp',fill='disp'),shape='s',colour="black")
    +scale_fill_gradient2(low="#377EB8",high="#E41A1C",limits =(0,np.max(mtcars.disp)),midpoint=np.mean(mtcars.disp))
    +scale_size_area(max_size=12)
    +geom_text(label=mtcars.disp,nudge_x=0.3,nudge_y=0.3)
    +theme(
        axis_title=element_text(size=18,face="plain",color="black"),
        axis_text=element_text(size=16,face="plain",color="black"),
        aspect_ratio =1.2,
        figure_size =(5,5),
        dpi=100
    ))
print(base_plot)

# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rc('font', size=13)
df = pd.read_csv('ThreeD_Scatter_Data.csv')
fig = plt.figure(figsize=(10, 8), dpi=90)
ax = fig.gca(projection='3d')
ax.view_init(azim=15, elev=20)

ax.grid(False)
ax.xaxis._axinfo['tick']['outward_factor'] = 0
ax.xaxis._axinfo['tick']['inward_factor'] = 0.4
ax.yaxis._axinfo['tick']['outward_factor'] = 0
ax.yaxis._axinfo['tick']['inward_factor'] = 0.4
ax.zaxis._axinfo['tick']['outward_factor'] = 0
ax.zaxis._axinfo['tick']['inward_factor'] = 0.4
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.xaxis.pane.set_edgecolor('k')
ax.yaxis.pane.set_edgecolor('k')
ax.zaxis.pane.set_edgecolor('k')
p = ax.scatter3D(df.mph, df.Gas_Mileage, df.Power, s=100, cmap='RDYlBu_r', edgecolor='k')

ax.set_xlabel('0-60 mph (sec)')
ax.set_ylabel('Gasileage(mpg)')
ax.set_zlabel('Power(kW)')
plt.show()
# Out:
# C:\Users\brokyz\AppData\Local\Temp\ipykernel_11608\2566145944.py:10: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().

# %%
df = pd.read_csv('ThreeD_Scatter_Data.csv')
fig = plt.figure(figsize=(10, 8), dpi=90)
ax = fig.gca(projection='3d')
ax.view_init(azim=15, elev=20)

ax.grid(False)
ax.xaxis._axinfo['tick']['outward_factor'] = 0
ax.xaxis._axinfo['tick']['inward_factor'] = 0.4
ax.yaxis._axinfo['tick']['outward_factor'] = 0
ax.yaxis._axinfo['tick']['inward_factor'] = 0.4
ax.zaxis._axinfo['tick']['outward_factor'] = 0
ax.zaxis._axinfo['tick']['inward_factor'] = 0.4
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.xaxis.pane.set_edgecolor('k')
ax.yaxis.pane.set_edgecolor('k')
ax.zaxis.pane.set_edgecolor('k')
scatter = ax.scatter3D(df.mph, df.Gas_Mileage, df.Power, c='#DF4736',
                       s=df.Weight*0.25, cmap='RdYlBu.r', edgecolor='k', alpha=0.8)
kw = dict(prop='sizes',num=5,c='#DF4736',func=lambda s: s/0.25)
ax.legend(*scatter.legend_elements(**kw),loc="center",bbox_to_anchor=(1.0,0,0,1),title="Weight")
ax.set_xlabel('0-60 mph (sec)')
ax.set_ylabel('Gasileage(mpg)')
ax.set_zlabel('Power(kW)')

plt.show()
# Out:
# C:\Users\brokyz\AppData\Local\Temp\ipykernel_11608\1974728783.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().

# %%
df = pd.read_csv('ThreeD_Scatter_Data.csv')
fig = plt.figure(figsize=(10, 8), dpi=90)
ax = fig.gca(projection='3d')
ax.view_init(azim=15, elev=20)

ax.grid(False)
ax.xaxis._axinfo['tick']['outward_factor'] = 0
ax.xaxis._axinfo['tick']['inward_factor'] = 0.4
ax.yaxis._axinfo['tick']['outward_factor'] = 0
ax.yaxis._axinfo['tick']['inward_factor'] = 0.4
ax.zaxis._axinfo['tick']['outward_factor'] = 0
ax.zaxis._axinfo['tick']['inward_factor'] = 0.4
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.xaxis.pane.set_edgecolor('k')
ax.yaxis.pane.set_edgecolor('k')
ax.zaxis.pane.set_edgecolor('k')
scatter=ax.scatter3D(df.mph, df.Gas_Mileage,df.Power,c=df.Weight,s=df.Weight*0.25,cmap='RdYlBu_r',edgecolor='k',alpha=0.8)
cbar=fig.colorbar(scatter, shrink=0.5,aspect=10)
cbar.set_label('Weight')
kw = dict(prop="sizes",num=5,func=lambda s: s/0.25)
ax.legend(loc='center right')
legend2=ax.legend(*scatter.legend_elements(**kw),loc="center right", title="Weight")
plt.show()
# Out:
# C:\Users\brokyz\AppData\Local\Temp\ipykernel_11608\3020942343.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
